# %%
##Cloud Type -15    N/A, Fill Flag 0    N/A, Fill Flag any   N/A

# %%
import pandas as pd

# %%
train=pd.read_csv('/content/drive/MyDrive/Wipro_data/train.csv',  parse_dates=['Year', 'Month', 'Day', 'Hour', 'Minute'])

# %%
train.head()
# Out:
#         Year Month Day  ... Wind Direction Wind Speed  Fill Flag
# 0 2009-01-01     1   1  ...          346.1        3.1          0
# 1 2009-01-01     1   1  ...          346.1        3.1          0
# 2 2009-01-01     1   1  ...          347.9        3.2          0
# 3 2009-01-01     1   1  ...          347.9        3.1          0
# 4 2009-01-01     1   1  ...          350.0        3.0          0
#
# [5 rows x 18 columns]

# %%
train=train.drop(columns=['Year' ,'Month', 'Day', 'Hour', 'Minute'], axis=0)

# %%
train.columns
# Out:
# Index(['Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI', 'Cloud Type',
#        'Dew Point', 'Temperature', 'Pressure', 'Relative Humidity',
#        'Solar Zenith Angle', 'Precipitable Water', 'Wind Direction',
#        'Wind Speed', 'Fill Flag'],
#       dtype='object')

# %%
train.isnull().sum()
# Out:
# Clearsky DHI          0
# Clearsky DNI          0
# Clearsky GHI          0
# Cloud Type            0
# Dew Point             0
# Temperature           0
# Pressure              0
# Relative Humidity     0
# Solar Zenith Angle    0
# Precipitable Water    0
# Wind Direction        0
# Wind Speed            0
# Fill Flag             0
# dtype: int64

# %%
DHI=train['Clearsky DHI']
DNI=train['Clearsky DNI']
GHI=train['Clearsky GHI']

# %%
train_data=train[['Cloud Type','Dew Point', 'Temperature', 'Pressure', 
                  'Relative Humidity','Solar Zenith Angle', 'Precipitable Water', 
                  'Wind Direction','Wind Speed', 'Fill Flag']]

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
train_data=scale.fit_transform(train_data.values)

# %%
DNI=DNI.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( train_data, DNI, test_size=0.23, random_state=42)

# %%
X_train.shape
# Out:
# (134977, 10)

# %%
import numpy as np
train_x=np.reshape(X_train, (X_train.shape[0], 1,X_train.shape[1]))
test_x=np.reshape(X_test, (X_test.shape[0], 1,X_test.shape[1]))

# %%
from sklearn.metrics import accuracy_score, mean_squared_error
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential 
from keras.layers import LSTM,Dense, Dropout

# %%
model=Sequential()
model.add(LSTM(units=128, input_shape=(1,10), return_sequences=True))
model.add(LSTM(units=64, return_sequences=True))
model.add(LSTM(units=32, return_sequences=True))
model.add(LSTM(units=16))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(train_x, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 4219/4219 [==============================] - 50s 12ms/step - loss: 136835.1250
# Epoch 2/50
# 4219/4219 [==============================] - 37s 9ms/step - loss: 136834.2344
# Epoch 3/50
# 4219/4219 [==============================] - 40s 9ms/step - loss: 136834.0000
# Epoch 4/50
# 4219/4219 [==============================] - 39s 9ms/step - loss: 136834.0625
# Epoch 5/50
# 4219/4219 [==============================] - 38s 9ms/step - loss: 136834.1719
# Epoch 6/50
# 4219/4219 [==============================] - 38s 9ms/step - loss: 136834.0312
# Epoch 7/50
# 4219/4219 [==============================] - 39s 9ms/step - loss: 136833.9688
# Epoch 8/50
# 4219/4219 [==============================] - 38s 9ms/step - loss: 136833.8750
# Epoch 9/50
# 4219/4219 [==============================] - 45s 11ms/step - loss: 136833.9375
# Epoch 10/50
# 4219/4219 [==============================] - 45s 11ms/step - loss: 136833.9219
# Epoch 11/50
# ...

# %%
model.evalute(test_x, y_test)

# %%
pred=model.predict(test)

# %%
test=pd.read_csv('/content/drive/MyDrive/Wipro_data/test.csv')

# %%
ldata_test=data_test.drop(columns=['Clearsky DHI','Clearsky DNI','Clearsky GHI'], axis=0)

# %%
data_test.head()
# Out:
#    Year  Month  Day  ...  Wind Direction  Wind Speed  Fill Flag
# 0  2019      1    1  ...             190         2.3          0
# 1  2019      1    1  ...             187         2.5          0
# 2  2019      1    1  ...             184         2.8          0
# 3  2019      1    1  ...             185         3.0          0
# 4  2019      1    1  ...             186         3.1          0
#
# [5 rows x 15 columns]
